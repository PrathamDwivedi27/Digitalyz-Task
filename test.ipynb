# %%
import pandas as pd

# %%
db = pd.read_excel("dataset.xlsx","Course list",index_col=0)

# %%
db.head()
# Out:
#                             Title  Length     Priority  \
# Course code
# ARTBND               Band - High      2.0  Core course
# ARTChor            Chorus - High      2.0  Core course
# ARTDRAW      Drawing and Painting     2.0  Core course
# ARTSTD1              Studio Art I     1.0  Core course
# ARTSTD2             Studio Art II     1.0  Core course
#
#                       Available blocks Unavailable blocks  \
# Course code
# ARTBND       1A, 1B, 2A, 2B, 3, 4A, 4B                NaN
# ARTChor      1A, 1B, 2A, 2B, 3, 4A, 4B                NaN
# ARTDRAW      1A, 1B, 2A, 2B, 3, 4A, 4B                NaN
# ARTSTD1      1A, 1B, 2A, 2B, 3, 4A, 4B                NaN
# ARTSTD2      1A, 1B, 2A, 2B, 3, 4A, 4B                NaN
#
#              Minimum section size  Target section size  Maximum section size  \
# Course code
# ARTBND                          7                   25                    40
# ARTChor                         7                   20                    40
# ...

# %%
db.index = db.index.map(lambda x: x.upper())

# %%
db.head()
# Out:
#                             Title  Length     Priority  \
# Course code
# ARTBND               Band - High      2.0  Core course
# ARTCHOR            Chorus - High      2.0  Core course
# ARTDRAW      Drawing and Painting     2.0  Core course
# ARTSTD1              Studio Art I     1.0  Core course
# ARTSTD2             Studio Art II     1.0  Core course
#
#                       Available blocks Unavailable blocks  \
# Course code
# ARTBND       1A, 1B, 2A, 2B, 3, 4A, 4B                NaN
# ARTCHOR      1A, 1B, 2A, 2B, 3, 4A, 4B                NaN
# ARTDRAW      1A, 1B, 2A, 2B, 3, 4A, 4B                NaN
# ARTSTD1      1A, 1B, 2A, 2B, 3, 4A, 4B                NaN
# ARTSTD2      1A, 1B, 2A, 2B, 3, 4A, 4B                NaN
#
#              Minimum section size  Target section size  Maximum section size  \
# Course code
# ARTBND                          7                   25                    40
# ARTCHOR                         7                   20                    40
# ...

# %%
db.to_json("course_list.json",orient="index",indent=4)
